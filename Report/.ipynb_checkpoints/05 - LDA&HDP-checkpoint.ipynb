# %%
import pandas as pd
import numpy as np
from pandas import read_csv

# %%
#import data

file = '/Users/ziyuanjiang/dstoolbox/AS2/Movie_database_BritishAmerican2000-2021.csv'
file_op = open(file,encoding='UTF-8')
names = ['IMDbRating','Title','Year','Genre','Plot','Actors']
data = read_csv(file_op, names=names)
data.head()
# Out:
#    IMDbRating                     Title  Year                      Genre  \
# 0         7.1                  Aberdeen  2000                      Drama
# 1         4.1                The Asylum  2000    Drama, Horror, Thriller
# 2         6.6                 The Beach  2000  Adventure, Drama, Romance
# 3         5.6             Beautiful Joe  2000              Comedy, Drama
# 4         6.3  My Best Friend's Wedding  1997     Comedy, Drama, Romance
#
#                                                 Plot  \
# 0  Kaisa is a Scot, a successful London lawyer, w...
# 1  Plagued by endless visions and nightmares, Jen...
# 2  Garland's novel centers on a young nicotine-ad...
# 3  In the Bronx, Joe (Sir Billy Connolly), an Iri...
# 4  A woman who, by a promise made years earlier, ...
#
#                                            Actors
# 0  Stellan Skarsgård, Lena Headey, Jean Johansson
# 1        Steffanie Pitt, Nick Waring, Ingrid Pitt
# 2   Leonardo DiCaprio, Tilda Swinton, Daniel York
# 3       Sharon Stone, Billy Connolly, Gil Bellows
# 4    Julia Roberts, Dermot Mulroney, Cameron Diaz

# %%
#data pre-processing
import re
import string

#punctuation
for row in data.itertuples():
    temp = str(getattr(row, 'Plot'))
    for i in string.punctuation:
        temp = temp.replace(i, '')
    data.loc[row.Index,'Plot'] = temp

# %%
#stopwords
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))
stop_words.update({"one","two"})

for row in data.itertuples():
    temp = str(getattr(row, 'Plot'))
    word_tokens = word_tokenize(temp, language='english',preserve_line=False)
    filtered_sentence = []
    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w)
    e = ' '.join([str(item).lower() for item in filtered_sentence])
    data.loc[row.Index,'Plot'] = e

# %%
from wordcloud import WordCloud
long_string = ','.join(list(data['Plot'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
#LDA
from pprint import pprint
import gensim
import gensim.corpora as corpora

data_words = []
for row in data.itertuples():
    temp = str(getattr(row, 'Plot'))
    word_tokens = word_tokenize(temp, language='english',preserve_line=False)
    data_words.append(word_tokens)


id2word = corpora.Dictionary(data_words)
texts = data_words
corpus = [id2word.doc2bow(text) for text in texts]
num_topics = 10
lda_model = gensim.models.LdaMulticore(corpus=corpus, id2word=id2word, num_topics=num_topics)

# %%
pprint(lda_model.print_topics(num_topics=20, num_words=10))
# Out:
# [(0,
#   '0.005*"however" + 0.005*"life" + 0.005*"show" + 0.004*"love" + 0.004*"must" '
#   '+ 0.003*"new" + 0.003*"world" + 0.003*"time" + 0.003*"jerry" + '
#   '0.003*"friend"'),
#  (1,
#   '0.004*"life" + 0.004*"man" + 0.003*"story" + 0.003*"steve" + 0.003*"frank" '
#   '+ 0.002*"new" + 0.002*"time" + 0.002*"young" + 0.002*"family" + '
#   '0.002*"house"'),
#  (2,
#   '0.007*"new" + 0.005*"lives" + 0.005*"life" + 0.004*"three" + 0.004*"school" '
#   '+ 0.004*"find" + 0.004*"real" + 0.004*"could" + 0.003*"better" + '
#   '0.003*"ever"'),
#  (3,
#   '0.004*"world" + 0.004*"years" + 0.004*"life" + 0.004*"young" + '
#   '0.003*"family" + 0.003*"father" + 0.003*"time" + 0.003*"new" + '
#   '0.003*"lives" + 0.003*"man"'),
#  (4,
#   '0.006*"life" + 0.005*"new" + 0.003*"young" + 0.003*"world" + 0.003*"story" '
#   '+ 0.003*"love" + 0.003*"old" + 0.002*"friends" + 0.002*"finds" + '
#   '0.002*"get"'),
#  (5,
#   '0.005*"life" + 0.005*"young" + 0.004*"family" + 0.003*"world" + 0.003*"new" '
#   '+ 0.003*"man" + 0.003*"find" + 0.003*"father" + 0.002*"get" + 0.002*"city"'),
#  (6,
#   '0.006*"life" + 0.004*"three" + 0.004*"leads" + 0.003*"lives" + '
#   '0.003*"boundaries" + 0.003*"bring" + 0.003*"ever" + 0.003*"time" + '
#   '0.003*"students" + 0.003*"begin"'),
#  (7,
#   '0.008*"show" + 0.006*"talk" + 0.005*"however" + 0.005*"must" + 0.005*"life" '
#   '+ 0.005*"host" + 0.005*"jerry" + 0.005*"perform" + 0.005*"family" + '
#   '0.004*"team"'),
#  (8,
#   '0.004*"new" + 0.004*"life" + 0.004*"home" + 0.003*"story" + 0.003*"love" + '
#   '0.003*"family" + 0.003*"young" + 0.003*"wife" + 0.003*"set" + '
#   '0.003*"world"'),
#  (9,
#   '0.006*"salo" + 0.004*"wife" + 0.004*"becomes" + 0.004*"story" + '
#   '0.004*"life" + 0.004*"jr" + 0.003*"new" + 0.003*"lives" + 0.003*"luck" + '
#   '0.003*"drug"')]

# %%
#HDP model
from gensim.models import HdpModel

hdp = HdpModel(corpus, id2word)
topic_info = hdp.print_topics(num_topics=20, num_words=10)

# %%
pprint(hdp.print_topics(num_topics=20, num_words=10))
# Out:
# [(0,
#   '0.006*life + 0.004*new + 0.004*family + 0.003*world + 0.003*young + '
#   '0.003*find + 0.003*man + 0.003*time + 0.003*get + 0.002*years'),
#  (1,
#   '0.004*life + 0.003*find + 0.003*new + 0.003*family + 0.002*must + '
#   '0.002*world + 0.002*young + 0.002*story + 0.002*man + 0.002*finds'),
#  (2,
#   '0.015*lives + 0.015*ever + 0.015*teachers + 0.014*could + 0.014*begin + '
#   '0.014*actors + 0.014*students + 0.014*three + 0.014*better + 0.014*onto'),
#  (3,
#   '0.020*salo + 0.010*becomes + 0.010*wife + 0.010*luck + 0.010*graces + '
#   '0.010*jr + 0.010*drug + 0.010*salvation + 0.010*reverend + 0.005*first'),
#  (4,
#   '0.004*life + 0.003*new + 0.002*finds + 0.002*time + 0.002*man + 0.002*love '
#   '+ 0.002*young + 0.002*world + 0.002*back + 0.002*mission'),
#  (5,
#   '0.003*young + 0.003*life + 0.002*family + 0.002*love + 0.002*story + '
#   '0.002*may + 0.002*new + 0.002*woman + 0.002*mother + 0.002*friends'),
#  (6,
#   '0.003*life + 0.003*new + 0.003*get + 0.002*love + 0.002*wants + 0.002*world '
#   '+ 0.002*family + 0.002*man + 0.002*time + 0.001*woman'),
#  (7,
#   '0.004*life + 0.003*show + 0.003*however + 0.002*new + 0.002*world + '
#   '0.002*family + 0.002*friend + 0.002*young + 0.002*years + 0.001*team'),
#  (8,
#   '0.003*new + 0.002*life + 0.002*world + 0.002*family + 0.002*back + '
#   '0.001*first + 0.001*girl + 0.001*years + 0.001*finds + 0.001*young'),
#  (9,
#   '0.025*show + 0.017*however + 0.017*talk + 0.017*perform + 0.017*jerry + '
#   '0.017*host + 0.009*must + 0.009*comedy + 0.009*becoming + 0.009*eventually'),
#  (10,
#   '0.003*home + 0.003*back + 0.003*comes + 0.003*angeles + 0.002*los + '
#   '0.002*victim + 0.002*childhood + 0.002*returns + 0.002*weekend + '
#   '0.002*south'),
#  (11,
#   '0.011*frank + 0.011*steve + 0.007*bob + 0.007*louis + 0.007*steves + '
#   '0.007*beachum + 0.004*night + 0.004*car + 0.004*journalist + 0.004*women'),
#  (12,
#   '0.002*family + 0.002*life + 0.001*young + 0.001*new + 0.001*world + '
#   '0.001*friends + 0.001*hes + 0.001*story + 0.001*knows + 0.001*love'),
#  (13,
#   '0.002*life + 0.001*family + 0.001*new + 0.001*war + 0.001*story + '
#   '0.001*john + 0.001*band + 0.001*personal + 0.001*time + 0.001*man'),
#  (14,
#   '0.013*new + 0.010*gabriella + 0.010*troy + 0.007*find + 0.007*school + '
#   '0.007*high + 0.006*friend + 0.004*drama + 0.004*week + 0.004*goes'),
#  (15,
#   '0.002*life + 0.001*years + 0.001*young + 0.001*world + 0.001*family + '
#   '0.001*lives + 0.001*new + 0.001*death + 0.001*also + 0.001*time'),
#  (16,
#   '0.001*world + 0.001*becomes + 0.001*life + 0.001*young + 0.001*find + '
#   '0.001*london + 0.001*family + 0.001*get + 0.001*must + 0.001*story'),
#  (17,
#   '0.002*story + 0.002*love + 0.001*find + 0.001*film + 0.001*soul + '
#   '0.001*life + 0.001*time + 0.001*going + 0.001*save + 0.001*set'),
#  (18,
#   '0.009*report + 0.007*together + 0.007*pass + 0.007*school + 0.007*bill + '
#   '0.007*ted + 0.005*help + 0.005*future + 0.005*stay + 0.003*called'),
#  (19,
#   '0.002*new + 0.001*high + 0.001*brother + 0.001*friend + 0.001*life + '
#   '0.001*stone + 0.001*young + 0.001*shuttle + 0.001*harry + 0.001*friends')]
